# %% [markdown]
# # Variable
#
# We use variable in our program to remember some information. Our program can change the value of these variable dynamically. For example, if we make a game, and we want to keep track of how many lives a player has, we need to use variable to remember this information.
#
# Usually people explains variable as a storage box that you can store information in. This is half correct in Python. It is best to understand the variable as two part: name and value.
#
# * Value: That's the information your program keep in the storage box. Just like the items you keep in your Minecraft chest.
# * Name: is NOT the storage box itself. Instead, it is the name we use to label the storage box, just like the sign we put on our Minecraft chest.
#
# Then what about the storage box itself? Do we call that something? Well, that's the memroy in your computer, a piece of semiconductor IC chip.
#
# ![image](https://drive.google.com/uc?export=view&id=1go4thmZbLSQiJ7OursFF-MoC-jqEwCFN)

# %%
# How to define a variable
a = "I am a variable"

# %% [markdown]
# When defining a variable, we start by creating a name, ie. ```a```, then followed with a equal sign ```=```, then followed with the value you want to store into the variable. In our example, it is ```"I am a variable"```.
#
# The ```=``` doesn't means equal. It means assigning. So the above code means assigning "I am a variable" sentence to variable a.
#
# Let's create a few more variables and store number in them.

# %%
b = 45
c = 2
d = b+c
print(b, '+', c, '=', d)

# %% [markdown]
# You can see that when a variable stores number, we can use the variable in math calculation.
#
# Variable must be defined and assigned a value before it can be used. In the following example, you can see that we first defined a variable ```a```, then print it. It can be display without error.
#
# But if we ask Python to print the variable ```image```, which is not defined. Python complaints, and gives us a ```NameError```

# %%
a = 34
print(a)
print(images)
# Out:
# 34
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc6aa053be7b> in <module>()
#       1 a = 34
#       2 print(a)
# ----> 3 print(images)
#
# NameError: name 'images' is not defined

# %% [markdown]
# ## Variable Naming Rules:
#
# When we create names for a variable, we have to follow the variable naming rules:
#
# * You can use numbers and letters and _ (underscore)
# * You CANNOT use space, or special characters % $^&@
# * Use _ to replace space, like today_time, box_a, user_input
# * Don’t use special command names like print, input
# * Don't use Python reserved words
# * Variable names are case sensitive: box_a and box_A are two different variables.
#
# ![reserved_words](https://drive.google.com/uc?export=view&id=1NMLzQErzEXzjkwTQK4spL8A36xHtILC-)

# %% [markdown]
# Which of these variable names violates the naming rule?
#
# * a, a1, an_apple, country56, the first country, print, globe, yield, player_score

# %% [markdown]
# # 2. Datatype
#
# * Ingeter
# * Float
# * String

# %% [markdown]
# ## 2.1 Integer
#
# Integer is the same concept as integer in math. They can be both positive or negative

# %%
a = 1
print("Type of a is ", type(a))
b = -10
print("Type of b is ", type(b))

# %% [markdown]
# * Python replied variable a and b are both <class 'int'>. That's the integer type.
#
# Note: we cannot use comma in numbers. 10,000 is not a valid form of number. In the example below, Python recgonize 10,000 as two seperate numbers.

# %%
a = 10,000
print(a)

# %% [markdown]
# ## 2.2 Float
#
# Float means floating point number. ie. 1.5, 125.746756, -0.542348, -234.3438

# %%
a = 0.5
print('Type of a is ', type(a))
b = -3412.659
print('Type of b is ', type(b))
c = 1.0
print('Type of c is ', type(c))
# Out:
# Type of a is  <class 'float'>
# Type of b is  <class 'float'>
# Type of c is  <class 'float'>

# %% [markdown]
# ## 2.3 Math Operators on Numbers

# %%
a = 2
b = 3
print("a+b=", a+b) # + is addition
print("b-a=", b-a) # - is subtraction
print("a*b=", a*b) # * is multiplication
print("b/a=", b/a) # / is division
print("b**a=", b**a) # ** is power

# %% [markdown]
# ## 2.4 String
#
# String plays an important part in programming. Programs need to process string to extract information from external world, and it needs to format string in order to display information to human.
#
# Unlike numbers (like int and float) that is natual to computer, string are not. String are for human. Computer understand things in number. Therefore under the hood, computer convert string to number in order to tell what character it is. The conversion follows the ASCII table.
#
# ![ascii table](https://cdn.shopify.com/s/files/1/1014/5789/files/Standard-ASCII-Table_large.jpg?10669400161723642407)
#
# In this table, look at the **Dec** column and **Char** column. We see that a symbol ```$``` is represented by number 36. A letter ```e``` is represented by number 101.
#
# Since computer recgonize everything by number, string must be categorize as a different datatype.
#
# * When Python know the datatype is string, and it sees number 36 in the memory, it converts that number to ```"$"```.
# * If Python knows the datatype is integer, and it sees number 36, it doesn't do any conversion.
#
# Let's use Python code to checkout the ASCII table. Feel free to try different numbers from the ASCII table **Dec** column.

# %%
chr(56)
# Out:
# '8'

# %%
a_number = 97
print("a_number is type",type(a_number))
print("Convert a_number to float:", float(a_number))
print("Convert a_number to string by ASCII table:", chr(a_number))

# %% [markdown]
# String is a series of character inside a pair of quotes. You can use single quote, double quotes, triple quotes. Python understand them all as string.

# %%
a_str = 'Hello world.'
b_str = "Nice to \n meet you."
c_str = """
My name is Henry.
I am from England
"""
#print(a_str, b_str, c_str)
print(a_str, '\n', b_str, c_str)

# %% [markdown]
# * This example shows three ways of creating a variable with string value. The triple quote allows us to write multi-line strings, while single quote and double quote can only be one line.
# * The second print statement used ```'\n'```. That is a special string telling Python to start a new line. Whenever Python sees '\n', it create a new line and continue printing.

# %% [markdown]
# ## 2.4 Number or string?
#
# When number is quoted, it is a string

# %%
a = 1 
b = '56' 
c = 12.8320
d = "44.349"

# %% [markdown]
# # 3 String Challenge
#
# *You can follow the next video on your study list to complete this challenge.*
#
# String type comes with lots of methods to help with manipulating strings. Let's look at a few.
# Work through this series of string challenge.
#
# Here is how to complete the challenge.
#
# * The challenges ask you to complete a function.
# * You should start typing your code on the next line where it says ```# Enter your code```.
# * Your code should line up with the ```#``` key.
# * Each challenge only requires one line of code.

# %%
# Make a function that build a sentence with person, verb, and place
#
# print(make_sentence("Jenny", "play", "palace"))
# >>> "Jenny play in a palance."
#
def make_sentence(person, verb, place):
  # Enter your code
  sentence = person + ' '+ verb + " in a " + place +'.' # example code entered by teacher
  return sentence

print(make_sentence("Jenny", "play", "palace"))

# %% [markdown]
# * upper() and lower()
#
# These two function convert all string to lower case or upper case, as the name suggests.

# %%
# Example
"This is my neat string".upper()

# %%
# Example
a_str = "This is my neat string"
a_str.lower()

# %%
# Make a function lowercase that, given a string, returns the 
# string, except in all lowercase letters.
#
# >>>> lowercase("ARG")
# arg
# >>>> lowercase("TRINKET")
# trinket

def lowercase(string):
  # Add code here that returns the answer
  string = string.lower()
  return string
  
# Add print statements here to see what your code does:
print(lowercase("ARG"))
print(lowercase("TRINKET"))

# %% [markdown]
# * Split
#
# We can split string by a particular character.

# %%
# Example
"Jonny Crane".split(" ")

# %%
# Example
"2021/06/23".split('/')

# %%
# Make a function that split the address string by comma
#
# split_address("34 Main Avenue,Ottawa,Ontario")
# >>>["34 Main Avenue", "Ottawa", "Ontario"]
#
def split_address(address):
  # Add code here that returns answer
  address = address.
  return address

print(split_address("34 Main Avenue,Ottawa,Ontario"))

# %% [markdown]
# * Combine String
#
# You can use ```+``` to combine strings.
#
# **When using ```+```, a number type variable must be converted to string type before it can be combined with other string.**

# %%
# Example
person = "Jenny"
age = 12
school = "Royal High"
sentence1 = person + " is " + str(age) + " years old."
sentence2 = "She goes to " + school
print(sentence1)
print(sentence2)

# %%
# Make a function to construct a sentence describing a person's height.
#
# print(build_sentence("Jenny", 168))
# >>> "Jenny is 168 cm tall."
#
def build_sentence(person, height):
  # Enter code here
  
  return sentence

print(build_sentence("Jenny", 168))

# %% [markdown]
# * Compare String
#
# You can compare if two string is the same with ```==```

# %%
# Example
name = input("Enter your name:")
if name == "Jenny Dawn":
  print("Access Granted")
else:
  print("You may not enter!")

# %%
# Complete the function that check whether the user answered "yes". 
#
# check_answer("yes")
# >>> "Your answer is yes."
# check_answer("what?")
# >>> "Terminating procedure."
#
def check_answer(answer):
  # Enter code here
  
    print("Your answer is yes.")
  else:
    print("Terminating procedure.")

answer = input("Make a choice, enter yes to proceed:")
check_answer(answer)

# %%
print(a > 1)
# Out:
# False

# %% [markdown]
# # Homework Project
#
# Silly Sentence
